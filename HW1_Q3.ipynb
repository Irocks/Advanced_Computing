# %%
# %config InlineBackend.figure_format='retina'
# %matplotlib inline

import numpy as np
np.random.seed(123)
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (8, 8)
plt.rcParams["font.size"] = 14
from sklearn.utils import check_random_state

# %%
#Question 3
#in logistic regression dependant variable is categorial

# %%
from sklearn.linear_model import LogisticRegression

def make_two_blobs(n_samples=400, cluster_std=2., random_state=42):
    rng = check_random_state(random_state)
    X = rng.multivariate_normal([5,0], [[cluster_std**2, 0], [0., cluster_std**2]],
                                size=n_samples//2)
    
    X2 = rng.multivariate_normal([0, 5.], [[cluster_std**2, 0], [0., cluster_std**2]],
                                 size=n_samples//2)
    X = np.vstack((X, X2))
    return X, np.hstack((np.ones(n_samples//2), np.zeros(n_samples//2)))

X, y = make_two_blobs()
labels = ['b', 'r']
y = np.take(labels, (y < 0.5))

# %%
plt.scatter(X[:,0], X[:,1],c=y)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.5)
plt.scatter(X_train[:,0],X_train[:,1] ,marker="^",c=y_train, label='train')
plt.scatter(X_test[:,0],X_test[:,1] ,marker=".",c=y_test, label='test')
plt.legend(loc='best')

# %%
#my guess would be on the diagonal between two bloobs as that would give a way to decide which colour to pick

# %%
logisticreg = linear_model.LogisticRegression()
logisticreg.fit(X_train, y_train)
coef=logisticreg.coef_
intercept=logisticreg.intercept_

# %%
xx1 = np.linspace(-6, 10, 100)
plt.scatter(X_train[:,0],X_train[:,1] ,marker="^",c=y_train, label='train')
plt.scatter(X_test[:,0],X_test[:,1] ,marker=".",c=y_test, label='test')
plt.legend(loc='best')
plt.plot(xx1, coef[:, 1] * xx1 + coef[:, 0], 'k')
