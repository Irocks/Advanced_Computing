# %%
# %config InlineBackend.figure_format='retina'
# %matplotlib inline

import numpy as np
np.random.seed(123)
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = (8, 8)
plt.rcParams["font.size"] = 14
from sklearn.utils import check_random_state

# %%
#Question 2
def make_regression(n_samples=100, noise_level=0.8, random_state=2):
    rng = check_random_state(random_state)
    X = np.linspace(-2, 2, n_samples)
    y = 2 * X + np.sin(5 * X) + rng.randn(n_samples) * noise_level
    return X.reshape(-1, 1), y

# %%
X, y = make_regression()

# %%
plt.plot(X,y, '.')
plt.xlabel("X")
plt.ylabel("y")

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.5)
plt.plot(X_train, y_train, '.g', label='train')
plt.plot(X_test, y_test, '.r', label='test')
plt.legend(loc='best')
plt.xlabel("X")
plt.ylabel("y")

from sklearn.neighbors import KNeighborsRegressor
rgr = KNeighborsRegressor(n_neighbors=3)
rgr.fit(X_train, y_train)
line = np.linspace(-2, 2, 100).reshape(-1, 1)
plt.plot(line, rgr.predict(line), '-b')

from sklearn.metrics import mean_squared_error
print('MSE train:', mean_squared_error(y_train, rgr.predict(X_train)))
print('MSE test:', mean_squared_error(y_test, rgr.predict(X_test)))
# Out:
# MSE train: 0.601141545431
# MSE test: 0.869095749997

# %%
plt.plot(X_train, y_train, '.g', label='train')
plt.plot(X_test, y_test, '.r', label='test')
plt.legend(loc='best')
plt.xlabel("X")
plt.ylabel("y")

rgr = KNeighborsRegressor(n_neighbors=4)
rgr.fit(X_train, y_train)
line = np.linspace(-2, 2, 100).reshape(-1, 1)
plt.plot(line, rgr.predict(line), '-b')
print('MSE train:', mean_squared_error(y_train, rgr.predict(X_train)))
print('MSE test:', mean_squared_error(y_test, rgr.predict(X_test)))
# Out:
# MSE train: 0.702801677154
# MSE test: 0.866600486256

# %%
plt.plot(X_train, y_train, '.g', label='train')
plt.plot(X_test, y_test, '.r', label='test')
plt.legend(loc='best')
plt.xlabel("X")
plt.ylabel("y")

rgr = KNeighborsRegressor(n_neighbors=5)
rgr.fit(X_train, y_train)
line = np.linspace(-2, 2, 100).reshape(-1, 1)
plt.plot(line, rgr.predict(line), '-b')
print('MSE train:', mean_squared_error(y_train, rgr.predict(X_train)))
print('MSE test:', mean_squared_error(y_test, rgr.predict(X_test)))
# Out:
# MSE train: 0.700794604043
# MSE test: 0.870559478771

# %%
plt.plot(X_train, y_train, '.g', label='train')
plt.plot(X_test, y_test, '.r', label='test')
plt.legend(loc='best')
plt.xlabel("X")
plt.ylabel("y")

rgr = KNeighborsRegressor(n_neighbors=6)
rgr.fit(X_train, y_train)
line = np.linspace(-2, 2, 100).reshape(-1, 1)
plt.plot(line, rgr.predict(line), '-b')
print('MSE train:', mean_squared_error(y_train, rgr.predict(X_train)))
print('MSE test:', mean_squared_error(y_test, rgr.predict(X_test)))
# Out:
# MSE train: 0.674334255545
# MSE test: 0.710201850149

# %%
plt.plot(X_train, y_train, '.g', label='train')
plt.plot(X_test, y_test, '.r', label='test')
plt.legend(loc='best')
plt.xlabel("X")
plt.ylabel("y")

rgr = KNeighborsRegressor(n_neighbors=7)
rgr.fit(X_train, y_train)
line = np.linspace(-2, 2, 100).reshape(-1, 1)
plt.plot(line, rgr.predict(line), '-b')
print('MSE train:', mean_squared_error(y_train, rgr.predict(X_train)))
print('MSE test:', mean_squared_error(y_test, rgr.predict(X_test)))
# Out:
# MSE train: 0.7708143945
# MSE test: 0.806003845417

# %%
plt.plot(X_train, y_train, '.g', label='train')
plt.plot(X_test, y_test, '.r', label='test')
plt.legend(loc='best')
plt.xlabel("X")
plt.ylabel("y")

rgr = KNeighborsRegressor(n_neighbors=8)
rgr.fit(X_train, y_train)
line = np.linspace(-2, 2, 100).reshape(-1, 1)
plt.plot(line, rgr.predict(line), '-b')
print('MSE train:', mean_squared_error(y_train, rgr.predict(X_train)))
print('MSE test:', mean_squared_error(y_test, rgr.predict(X_test)))
# Out:
# MSE train: 0.787141271262
# MSE test: 0.896158218377

# %%
plt.plot(X_train, y_train, '.g', label='train')
plt.plot(X_test, y_test, '.r', label='test')
plt.legend(loc='best')
plt.xlabel("X")
plt.ylabel("y")

rgr = KNeighborsRegressor(n_neighbors=9)
rgr.fit(X_train, y_train)
line = np.linspace(-2, 2, 100).reshape(-1, 1)
plt.plot(line, rgr.predict(line), '-b')
print('MSE train:', mean_squared_error(y_train, rgr.predict(X_train)))
print('MSE test:', mean_squared_error(y_test, rgr.predict(X_test)))
# Out:
# MSE train: 0.848003390781
# MSE test: 0.949828041528

# %%
plt.plot(X_train, y_train, '.g', label='train')
plt.plot(X_test, y_test, '.r', label='test')
plt.legend(loc='best')
plt.xlabel("X")
plt.ylabel("y")

rgr = KNeighborsRegressor(n_neighbors=10)
rgr.fit(X_train, y_train)
line = np.linspace(-2, 2, 100).reshape(-1, 1)
plt.plot(line, rgr.predict(line), '-b')
print('MSE train:', mean_squared_error(y_train, rgr.predict(X_train)))
print('MSE test:', mean_squared_error(y_test, rgr.predict(X_test)))
# Out:
# MSE train: 0.882083380725
# MSE test: 1.09307756482

# %%
from numpy import ndarray
MSE_train = ndarray((13,),float)
MSE_test= ndarray((13,),float)
neigh= ndarray((13,),float)
for i in range(3,16):
    rgr = KNeighborsRegressor(n_neighbors=i)
    rgr.fit(X_train, y_train)
    MSE_train[i-3] = mean_squared_error(y_train, rgr.predict(X_train))
    MSE_test[i-3] = mean_squared_error(y_test, rgr.predict(X_test))
    neigh[i-3]=i

# %%
plt.plot(neigh, MSE_train, '.g', label='train')
plt.plot(neigh, MSE_test, '.r', label='test')
plt.legend(loc='best')
plt.xlabel("number of neighbours")
plt.ylabel("Mean Squared Error")

# %%
#MSE for training data is increasing as the function is modelled like a picewice constant avereged over k neighbours
#MSE for testing data first seems to decrease and then increase
#minimum value of MSE for testing data is 8 which is the best for our data set and particular division to training/test data
#apriori without looking how data was generated it is not clear what should be the value of MSE for the best number of neighbours
#cheating and looking at the data generated function one may notice that amplitude of noise is 0.8 which is close to the MSE for training dataset
